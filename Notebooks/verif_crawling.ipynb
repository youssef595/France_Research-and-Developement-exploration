# %%
import sys
sys.path.append("../src/")
from verif_crawler import CrawlerVerif
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../Data/entreprise_RD_v1.csv')
companies_ids = df['siren'].unique().tolist()[0:2]
companies_names = df['libellé'].unique().tolist()[0:2]

# %%
crawler = CrawlerVerif(companies_names, companies_ids)

# %%
crawler.crawl_over_all_companies()
# Out:
# #2  Company: DEVOLDER LAURENCE-LOLA
# No Found Data
# Execution Time: 0.41988062858581543 seconds
#
# Stealing's well done!

# %%
crawler.output_df
# Out:
#        SIREN           Nom du compte Annee  Chiffre d'affaires  \
# 0  526020482          HUCHEZ TREUILS  2020                 NaN
# 1  526020482          HUCHEZ TREUILS  2019                 NaN
# 2  526020482          HUCHEZ TREUILS  2018           8158226.0
# 3  526020482          HUCHEZ TREUILS  2017                 NaN
# 4  526020482          HUCHEZ TREUILS  2016           7498031.0
# 5  508178381  DEVOLDER LAURENCE-LOLA   NaN                 NaN
#
#    Charges d'exploitation  Bénéfice ou Perte Fonds propres  \
# 0                     NaN                NaN       5071571
# 1                     NaN                NaN       3446344
# 2               8484770.0           241504.0       3502988
# 3                     NaN                NaN       3318988
# 4               7497214.0           432256.0       3140468
# 5                     NaN                NaN           NaN
#
#   Immobilisations nettes Trésorerie Dettes financières Total bilan  \
# ...
